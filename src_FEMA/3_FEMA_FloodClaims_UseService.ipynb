# %% [markdown]
# ## Explore FEMA table service
# This notebook explores how the ArcGIS API for Python can access and analyzed web services

# %%
#Packages
import pandas as pd
from arcgis.gis import GIS
from arcgis.features import GeoAccessor, FeatureLayerCollection

# %%
#Login to GIS
gis = GIS("home")

# %%
#Get the Table Service
items = gis.content.search('title:"FEMA_FloodClaims" AND owner:jpfay_dukeuniv')
table_layer = items[1]
type(table_layer)
# Out:
# arcgis.gis.Item
